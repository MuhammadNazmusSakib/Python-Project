# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure



# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create



#Read in the data

df = pd.read_csv('H:\Python\movies.csv')

# %%
# Look at the data
    
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# let's see if there is any missing data

for col in df.columns:
    pct_missing = np.sum(df[col].isnull())
    print('{} = {}'.format(col, pct_missing))
# Out:
# name = 0
# rating = 77
# genre = 0
# year = 0
# released = 2
# score = 3
# votes = 3
# director = 0
# writer = 3
# star = 1
# country = 3
# budget = 2171
# gross = 189
# company = 17
# runtime = 4

# %%
# Data type for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Replacing empty cell by 0

df = df.fillna({'score': 0, 'votes': 0, 'budget': 0, 'gross': 0, 'runtime': 0})

# df.score.replace(np.nan, 0)

# %%
# Change data type of columns

df.score = df.score.astype('int64')
df.votes = df.votes.astype('int64')
df.budget = df.budget.astype('int64')
df.gross = df.gross.astype('int64')
df.runtime = df.runtime.astype('int64')

# df['score'] = df['score'].astype('int64')

# %%
# Replacing inappropriate information

df = df.replace(np.nan, 'No Information') # replacing all null values

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df['Year_Correct'] = df.released.astype(str).str.extract(', (\w*\ ?)')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# sorting by a particular column

df = df.sort_values(by = ['gross'], inplace = False, ascending = False)

# %%
# showing the whole table

pd.set_option('display.max_row', None)

# %%
# Drop any duplicates

df.name.drop_duplicates().sort_values(ascending = True).head()
# Out:
# 6569                        '71
# 1006            'Round Midnight
# 1013             'night, Mother
# 1099    *batteries not included
# 6906        10 Cloverfield Lane
# Name: name, dtype: object

# %%
# Scatter plot with budget vs gross
# 'b' = blue,'g' = green,'r' = red,'c' =  cyan ,'m' = magenta,'y' = yellow,'k' = black,'w' = white

plt.scatter(x = 'budget', y = 'gross', data = df, color = 'c')

# plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Gross Earning')
plt.ylabel('Budget')
plt.show()

# %%
# Plot budget vs gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {'color': 'm'}, line_kws = {'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# creating correlation

df.corr(method = 'kendall') # 'pearson', 'spearman', 'kendall'
# Out:
# C:\Users\Sakib\AppData\Local\Temp\ipykernel_9280\166223932.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method = 'kendall') # 'pearson', 'spearman', 'kendall'
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.072389  0.330410  0.209304  0.216595  0.096390
# score    0.072389  1.000000  0.319009 -0.003361  0.100147  0.299543
# votes    0.330410  0.319009  1.000000  0.439883  0.560449  0.197697
# budget   0.209304 -0.003361  0.439883  1.000000  0.541956  0.176184
# gross    0.216595  0.100147  0.560449  0.541956  1.000000  0.177429
# runtime  0.096390  0.299543  0.197697  0.176184  0.177429  1.000000

# %%
# visualizing correlation

correlation_matrix = df.corr(method = 'spearman') # 'pearson', 'spearman', 'kendall'
sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()
# Out:
# C:\Users\Sakib\AppData\Local\Temp\ipykernel_9280\1380853926.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method = 'spearman') # 'pearson', 'spearman', 'kendall'

# %%
# Numerizing the table

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime  Year_Correct
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0            29
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0            39
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0            17
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0            35
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0            38

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# creating correlation

df_numerized.corr(method = 'spearman') # 'pearson', 'spearman', 'kendall'
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.012326  0.015940  0.011978 -0.010691  0.012733
# rating       -0.012326  1.000000  0.124526  0.000430  0.032526  0.026195
# genre         0.015940  0.124526  1.000000 -0.081261  0.030356  0.059851
# year          0.011978  0.000430 -0.081261  1.000000  0.000234  0.095526
# released     -0.010691  0.032526  0.030356  0.000234  1.000000  0.038362
# score         0.012733  0.026195  0.059851  0.095526  0.038362  1.000000
# votes         0.008574  0.022115 -0.204256  0.468107 -0.014421  0.412957
# director      0.008912  0.010241 -0.016710 -0.019843 -0.001265  0.021830
# writer        0.009861  0.001967  0.004099 -0.008156 -0.003288  0.021874
# star          0.006919  0.016817 -0.004348 -0.027382  0.015461  0.002725
# country      -0.007659  0.024547 -0.067679 -0.088250 -0.028091 -0.205178
# budget        0.015350 -0.098347 -0.316964  0.291152 -0.007802 -0.004378
# ...

# %%
# visualizing correlation

correlation_matrix = df_numerized.corr(method = 'spearman') # 'pearson', 'spearman', 'kendall'
sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df_numerized.corr()
corr_pair = correlation_mat.unstack()
corr_pair.head()
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
# dtype: float64

# %%
sorted_pairs = corr_pair.sort_values()
sorted_pairs.head()
# Out:
# budget  genre    -0.356564
# genre   budget   -0.356564
#         gross    -0.235650
# gross   genre    -0.235650
# rating  budget   -0.176002
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > .5]
high_corr
# Out:
# gross         votes           0.632870
# votes         gross           0.632870
# budget        gross           0.750157
# gross         budget          0.750157
# Year_Correct  year            0.992136
# year          Year_Correct    0.992136
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# Year_Correct  Year_Correct    1.000000
# dtype: float64
